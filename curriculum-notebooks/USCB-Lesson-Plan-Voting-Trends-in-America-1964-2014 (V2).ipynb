# %% [markdown]
# # Voting Trends in America, 1964-2014
#
# ---
#
# This notebook focuses on analyzing bar and line graphs by showing the percentages of people (by race, age, sex, region, and education) who voted in elections between 1964 and 2014. Students will use these data to respond to the question “Who votes in American elections?”
#
# ---
#
# ### Topics Covered
# - What is the Census?
# - Bar and Line Graphs
# - U.S Constitution
# - Voting Trends
#
# ### Table of Contents
#
# [Overwiew](#overwiew)<br>
#
#
# 1 - [Why the Census](#1)<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.1 - [How is the data used?](#s1.1)
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 1.2 - [Census and Congresional Represenation](#s1.2)
#
# 2 - [Vocabulary](#2)<br>
#
# 3 - [Part I](#3)<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.1 - [Analyze the Data](#s3.1)
#
#
# 4 - [Part II](#4)<br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; 3.1 - [Write Your Response](#s4.1)
#
#
# 5 - [Bibliography](#5)<br>
#
# ---
#
# ## Overview <a id='overwiew'></a>
#
# In this [lesson](https://www.census.gov/programs-surveys/sis/activities/history/voting-trends.html) plan you will analyze bar and line graphs showing the percentage of people (by race, age, sex, region, and eduation) who voted in elections between 1964 and 2014.
#
# You will do this by:
# 1. reading and understanding several years of data presented in bar graphs and line graphs.
# 2. identifying voting trends by race, year, and region.
# 3. comparing, analyzing, and evaluating voter registration and voting information to write a detailed response. <br>
#
# ---

# %%
#Press 'Shift' + 'Enter' to run this code! It will help load graph, charts, and tables that this lesson has!

import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import zipfile
from IPython.display import Image

pd.set_option('max_colwidth', 280)
# %matplotlib inline
plt.style.use('fivethirtyeight')
import seaborn as sns
sns.set() 
sns.set_context("talk")
import re
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import ipywidgets as widgets
# %matplotlib inline

import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual

# %% [markdown]
# **Tip**: When you're done reading each part of this lesson, press the **'Shift' + 'Enter' keys at the same time** to quickly move through each 'cell' and run the code!
#
# ---

# %% [markdown]
# # 1. Why the Census? <a id='1'></a>
#
# <div class="alert alert-info">
# <b> Question:</b>
# <!--But before we dive in, let's answer a question you might have:--> Why are we learning about statistics through Census data? In fact, why do we even care about the Census in the first place?
# </div>
#
# Depending on how old you are, you might or might not have watched your family or guardian fill out a long form about a decade ago that had some specific, slightly invasive questions like:
# 1. How many people live or stay in this house, apartment, or mobile home?
# 2. What is the name of the person who owns this house, apartment, or mobile home?
# 3. How old is the person who owns this house, apartment, or mobile home? When is his or her birthday?

# %% [markdown]
# ## 1.1 How is the Data Used?<a id='s1.1'></a>
#
# The census form is a way for the government to get a good idea as to **who** it is serving, which is: **YOU!** The government uses data it gets from this nation-wide Census to determine funding distributions across U.S. communities, as well as understand where community services are needed and how to implement them. Because of the Census, your neighborhood and city can improve education and transportation, promote public health, and use given money to make improvements. More services can be given to the elderly, new roads and schools can be built, and more job training centers can be maintained and established. *Everyone* benefits.

# %% [markdown]
# ## 1.2 Census and Congresional Represenation <a id='s1.2'></a>
#
# The amount of representation that your state has changes within Congress (in the U.S. House of Representatives) every ten years, when the Census is distributed. The voices of those vouching for your state's well-being in Congress could change or stay the same. Additionally, the representative (or "voice") representing your community in local, state, and federal governments could change, because district lines are redrawn every time. Members of Congress, state legislators, and many county and municipal offices are elected by voters grouped into districts, and you could be voting for different people depending on how these lines are drawn. These representatives are your spokespeople - their job is to listen to your needs and support government policies that will help your community!
#
# For more information, check out this document [here](https://www2.census.gov/programs-surveys/sis/resources/census101.pdf), designed to inform students like you on why the Census is so important! And for more reading on the confusing topic of re-districting, read [here](https://www.brennancenter.org/analysis/7-things-know-about-redistricting).
#
# ---

# %% [markdown]
# # 2. Vocabulary <a id='2'></a>
#
# Here are terms you should be familiar with before getting started with the lesson plan.
# * **Election** – a formal and organized process for choosing leaders and representatives for a group <br>
# * **Vote** – a formal way to choose between two or more people or things <br>
# * **Citizen** – a person who can vote in a specific state or nation <br>
# * **Suffrage** – the right to vote <br>
# * **Registered voter** – a person who signed up ahead of time to vote by proving citizenship <br>
# * **Presidential election** – an election, held every four years in the United States, to choose a president and
# vice president <br>
# * **Congressional election** – an election, held every two years in the United States, to choose certain
# members of Congress
#
# The original Consitution left the issue of voting rights to individual states, but 6 ammendment helped inform state law. Here are a list of the 6 ammendments:
#
#  * The **14th Amendment** said that men older than 21 can vote. <br>
#  * The **15th Amendment** said that people of any race can vote. <br>
#  * The **19th Amendment** gave women the right to vote. <br>
#  * The **23rd Amendment** gave citizens in the District of Columbia the right to vote in presidential elections. <br>
#  * The **24th Amendment** got rid of poll taxes in elections for federal officials. <br>
#  * The **26th Amendment**  lowered the voting age to 18.

# %% [markdown]
# ---

# %% [markdown]
# # 3. Part 1 <a id='3'></a>

# %% [markdown]
# ## 3.1 Analyze the Data <a id='s3.1'></a>

# %% [markdown]
# Let's firt start off by looking at **Item 1: Percent Voting by Race and Region of Total Voting-Age Population in Presidential Elections.** This graph represents the voting by race in both the North and South of the United States.

# %%
#Run this code to see Item 1 by pressing 'Shift' + 'Enter'


# whiteNorth = [75, 72, 68, 62, 63, 65, 60, 67, 57, 58, 63, 62, 58] 
# whiteSouth = [59, 62, 59, 59, 59, 59, 56, 61, 54, 55, 58, 59, 55]

# blackNorth = [72, 65, 60, 53, 55, 59, 56, 54, 52, 53, 56, 58, 63]
# blackSouth = [43, 52, 48, 45, 49, 52, 47, 56, 50, 54, 55, 65, 67]

# years1 = np.arange(1964, 2015, 4)

# part1 = pd.DataFrame(data={'Years':years1, 'White North':whiteNorth, 'White South': whiteSouth, 'Black North':blackNorth, 'Black South':blackSouth})

# item1 = plt.figure(figsize=(10, 7))

# for ppl in list(part1.columns[1:]):
#     sns.lineplot(x='Years', y=ppl, data=part1, label=ppl)        
    
# plt.ylim(0, 100)
# plt.ylabel('% Voting')
# plt.xticks(years1)
# plt.title('Percent Voting by Race and Region of Total Voting-Age Population in Presidential Elections')
# plt.legend()


url = 'https://www.census.gov/content/dam/Census/library/visualizations/time-series/demo/a7-elections.jpg'
Image(url,width=1500, height=1000)

# %% [markdown]
# Now let's answer a few questions about the graph that we see displayed above. For **questions 1-4** make sure you are taking a look at the years of the line-graph.

# %% [markdown]
# <div class="alert alert-info">
#
# 1. What is the first year? Click on the dropdown to answer.
#
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['1963', '1964', '1988'],
    #v#alue='1963',
    description='First Year:',
    disabled=False,
)
# Out:
# Dropdown(description='First Year:', options=('1963', '1964', '1988'), value='1963')

# %% [markdown]
# <div class="alert alert-info">
# 2. What is the last year? Click on the dropdown to answer.
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['1988', '1994', '2012'],
    #v#alue='1963',
    description='First Year:',
    disabled=False,
)
# Out:
# Dropdown(description='First Year:', options=('1988', '1994', '2012'), value='1988')

# %% [markdown]
# <div class="alert alert-info">
# 3.  How many years does it take to get from the first year to the next year, and so on? Why is the information in the graph available for only those years? Click on the dropdown below to answer.
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['1', '10', '4'],
#     value='pineapple',
    description='Years:',
    disabled=False
)
# Out:
# Dropdown(description='Years:', options=('1', '10', '4'), value='1')

# %% [markdown]
# <div class="alert alert-info">
# 4. How many election years does the graph show in total? Click on the buttons below to answer.
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['12', '13', '5'],
#     value='pineapple',
    description='Years:',
    disabled=False
)
# Out:
# Dropdown(description='Years:', options=('12', '13', '5'), value='12')

# %% [markdown]
# <div class="alert alert-info">
# 5. When you look at the line for black southern voters, what do you notice? Click on the drop down below to answer.
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['presedential elections went down','presidential elections went up', '5'],
    description='Answers:',
    disabled=False
)
# Out:
# Dropdown(description='Answers:', options=('presedential elections went down', 'presidential elections went up'…

# %% [markdown]
# <div class="alert alert-info">
# 6. Between 1964 and 2012, which three groups’ voting rates went down overall? Click on the drop down below to answer.
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['white north, black north, white south','white south, black south, white north', 'white south, black south, black north'],
    description='Answers:',
    disabled=False
)
# Out:
# Dropdown(description='Answers:', options=('white north, black north, white south', 'white south, black south, …

# %% [markdown]
# <div class="alert alert-info">
# 7. Overall, which group’s voting rate stayed mostly the same between 1964 and 2012? Click on the drop down below to answer.
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'
widgets.Dropdown(
    options=['white north','white south', 'black north'],
    description='Answers:',
    disabled=False
)
# Out:
# Dropdown(description='Answers:', options=('white north', 'white south', 'black north'), value='white north')

# %% [markdown]
# Before moving away from question 4, let's consider a few things. The percentage of black southern voters increased substantially and the percentage of white nonsouthern voters decreased. There was a sharp decline from
# 1964 to 1976 in the rates for black northern voters, a decrease between 1976 and 1996, and then increased steadily between 1996 and 2012.

# %% [markdown]
#  ----

# %% [markdown]
# Now let's look at **Item 2: Percent Registering and Voting by Race and Hispanic or Latin Origin, Presidential Elections**. This graph represents the percent of registered voters who did not vote and those who were registered and did vote by race and Hispanic origin.

# %%
#Run this code to see Item 2 by pressing 'Shift' + 'Enter'
url = 'https://www.census.gov/content/dam/Census/library/visualizations/time-series/demo/a6-presidential.jpg'
Image(url,width=1500, height=1000)

# %% [markdown]
# Now let's answer a few questions about the graph that we see displayed above.

# %% [markdown]
# <div class="alert alert-info">
# 8. What is the first year in the bar graph? Click on the drop down to answer.
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['1981', '1980', '2007'],
    #v#alue='1963',
    description='Answers:',
    disabled=False,
)
# Out:
# Dropdown(description='Answers:', options=('1981', '1980', '2007'), value='1981')

# %% [markdown]
# <div class="alert alert-info">
# 9. What is the last year in the bar graph? Click on the drop down to answer.
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['2002', '1980', '2012'],
    #v#alue='1963',
    description='Answers:',
    disabled=False,
)
# Out:
# Dropdown(description='Answers:', options=('2002', '1980', '2012'), value='2002')

# %% [markdown]
# Before moving on to question 10, note that registration and voting data are available for white,
# black, and Hispanic voters for all these years, but that data for Asian voters are available only from
# 1992 to 2012.

# %% [markdown]
# <div class="alert alert-info">
# 10. What do the dark and light green colors mean? Click on the drop down to answer
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['to look pretty', 'light green: percent registered, but didn not vote, dark green: percent voted'],
    description='Answers:',
    disabled=False,
)
# Out:
# Dropdown(description='Answers:', options=('to look pretty', 'light green: percent registered, but didn not vot…

# %% [markdown]
# <div class="alert alert-info">
# 11. Looking at the information for the four racial/ethnic groups side by side, what do you notice? Click on the drop down to answer.
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['all are the pretty much the same', 'Asian and Hispnanic votes had higher voting rates', 'White and Black voters had higher voting rates'],
    description='Answers:',
    disabled=False,
)
# Out:
# Dropdown(description='Answers:', options=('all are the pretty much the same', 'Asian and Hispnanic votes had h…

# %% [markdown]
# <div class="alert alert-info">
# 12. Now, looking at the light green bars for 2012, rank the four racial/ethnic groups from highest to lowest according to the percentages of people who actually voted in the presidential election that year. Click on the drop down to answer.
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['1. White, 2. Asian, 3. Hispanic, 4. Black', 
             '1.Black, 2. Hispanic, 3. Asian, 4. White',
             '1. Black, 2. White, 3. Hispanic, 4. Asian',],
    description='Answers:',
    disabled=False,
)
# Out:
# Dropdown(description='Answers:', options=('1. White, 2. Asian, 3. Hispanic, 4. Black', '1.Black, 2. Hispanic, …

# %% [markdown]
# <div class="alert alert-info">
# 13. Summarizes the voting trends of white voters and black voters during the presidential elections of 2004, 2008, and 2012. Click on the drop down to answer.
# drop down to answer.
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['hispanic peoeple who voted went down', 
             'black voters went up while white voters went down',
             'white voters went up, while black voters went down'],
    description='Answers:',
    disabled=False,
)
# Out:
# Dropdown(description='Answers:', options=('hispanic peoeple who voted went down', 'black voters went up while …

# %% [markdown]
# ---

# %% [markdown]
# Finally, let's look at **Item 3: Voting and Registration Graphs, Congressional Elections, 2014**. These graphs represent the percent of voting registered voters by age and sex.

# %%
#Run this code to see Item 3 by pressing 'Shift' + 'Enter'
def rotated(array_2d):
    list_of_tuples = zip(*array_2d) #add [::-1] to reverse order
    return [list(elem) for elem in list_of_tuples]


#AGE PLOTS
ageRanges = ["18-29", "30-39", "40-49", "50-59", "60-69", "70+"]
legend = ["Voted", "Registered, no vote", "Not Registered", "No Response"]

eighteen = [20, 27, 31, 22]
thirty = [33, 30, 20, 17]
fourty = [40, 27, 18, 15]
fifty = [48, 20, 15, 17]
sixty = [59, 17, 12, 12]
seventy = [59, 17, 12, 12]

combined = list(rotated([eighteen, thirty, fourty, fifty, sixty, seventy]))
xrange = np.arange(1, 7)

ages = plt.figure(1, figsize=(10, 7))
# Voted
plt.bar(x=xrange, height=combined[0], color='navy', label='Voted')
# Registered, no vote
plt.bar(x=xrange, height=combined[1], bottom=combined[0], color='magenta', label='Registered, no vote')
# Not Registered
plt.bar(x=xrange, height=combined[2], bottom=[i+j for i,j in zip(combined[0], combined[1])], color='turquoise', label='Not Registered')
# No Response
plt.bar(x=xrange, height=combined[3], bottom=[i+j+k for i,j,k in zip(combined[0], combined[1], combined[2])], color='red', label='No Response')
plt.legend()
plt.title('Voting and registration by age in United States: 2014')
plt.xticks(xrange, ageRanges)
plt.ylabel('%')
ages.show()


#GENDER PLOTS
male = [40, 23, 20, 17]
female = [42, 25, 16, 17]

combined2 = list(rotated([male, female]))
xrange2 = np.arange(1, 3)

genders = plt.figure(2, figsize=(10, 7))
# Voted
plt.bar(x=xrange2, height=combined2[0], color='navy', label='Voted', figure=genders)
# Registered, no vote
plt.bar(x=xrange2, height=combined2[1], bottom=combined2[0], color='magenta', label='Registered, no vote', figure=genders)
# Not Registered
plt.bar(x=xrange2, height=combined2[2], bottom=[i+j for i,j in zip(combined2[0], combined2[1])], color='turquoise', label='Not Registered', figure=genders)
# No Response
plt.bar(x=xrange2, height=combined2[3], bottom=[i+j+k for i,j,k in zip(combined2[0], combined2[1], combined2[2])], color='red', label='No Response', figure=genders)
plt.legend()
plt.title('Voting and registration by sex in United States: 2014')
plt.xticks(xrange2, ['Male', 'Female'])
plt.ylabel('%')
genders.show()
# Out:
# /Users/jarellymartin/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning:
#
# Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#
# /Users/jarellymartin/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning:
#
# Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# <div class="alert alert-info">
# 14. Looking at the graph on voting and registration by age, how do the percentages change as you read the information going from younger to older voters? Click on the drop down to answer.
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['percentages of people who votes goes up from older to younger people', 
             'there are no differences between older and younger people',
             'percentages of people who votes goes up from younger to older people'
             'female'],
    description='Answers:',
    disabled=False,
)
# Out:
# Dropdown(description='Answers:', options=('percentages of people who votes goes up from older to younger peopl…

# %% [markdown]
# <div class="alert alert-info">
# 15. Looking at the graph on voting and registration by sex, which percentage of voters is greater: male or female? Click on the drop down to answer.
# </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['male', 
             'female'],
    description='Answers:',
    disabled=False,
)
# Out:
# Dropdown(description='Answers:', options=('male', 'female'), value='male')

# %% [markdown]
# <div class="alert alert-info">
# 16. Looking at the graph on voting and registration by education, how does education relate to voting and registration rates? Click on the drop down to answer.
#     </div>

# %%
#Run this code to see a dropdown menu by pressing 'Shift' + 'Enter'

widgets.Dropdown(
    options=['there are no changes',' Voting and registration rates increase with higher levels of education',
             'voting and registration rates decrease with higher levels of education'],
    description='Answers:',
    disabled=False,
)
# Out:
# Dropdown(description='Answers:', options=('there are no changes', ' Voting and registration rates increase wit…

# %% [markdown]
# ---

# %% [markdown]
# # 4. Part 2  <a id='4'></a>
#
# ## 4.1 Write Your Response  <a id='s4.1'></a>

# %% [markdown]
# Answer the question, "Who votes in American elections?" Feel free to speak with your peers to work through some ideas. Also, make sure you include specific examples from the analysis you made about the above data sets. Your response should be a couple of sentences to a paragraph.

# %% [markdown]
# **Your answer:** Type your answer here

# %% [markdown]
# ---

# %% [markdown]
# **Congratulations!** You just finished Part 3 of this lesson! Make sure to click 'File', then 'Save and Checkpoint' in the upper left-hand corner to save all the hard work you've done!
#
#
# Now you know how to analyze bar and line graphs using the percentage of people (by race, age, sex, region, and eduation) who voted in elections between 1964 and 2014.
#
# You can now:
# 1. read and understand several years of data presented in bar graphs and line graphs.
# 2. identify voting trends by race, year, and region.
# 3. compare, analyze, and evaluate voter registration and voting information to write a detailed response.

# %% [markdown]
# ---
#
# ## 5. Bibliography  <a id='5'></a>
#
# **Notebook developed by:** im Fong, David Jeong, and Brian Yang
#
# **Modified by:** Varsha Vaidyanath, Jarelly Martin, Yuyang Zhong, and Sandeep Sainath
#
# **Date:** August 4, 2019
#
# **Using:** https://www.census.gov/programs-surveys/sis/activities/history/voting-trends.html
#
# **Suggested Grade Level:** 9-12
#
# **Data Science Discovery Program:** http://data.berkeley.edu/education/module
